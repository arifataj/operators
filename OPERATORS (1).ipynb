# %% [markdown]
# OPERATORS
#
# Arithematic operators
#
#  Assignt operators
#
# comparison operators
#
# logical operators
#
#
#
# Arithematic operators
#
#  addition
#
# substraction
#
#  multiplication
#
#   divition
#
#   modulus
#
#  exponantiaion
#
#   floor division

# %% [markdown]
# #addition

# %%
a=40
b=10
c=a+b
print(c)
# Out:
# 50

# %%
a=20
b=10
print(a+b)
# Out:
# 30

# %% [markdown]
# # substraction

# %%
a=15
b=25
c=a-b
print(c)
# Out:
# -10

# %%
a=43
b=23
print(a-b)
# Out:
# 20

# %% [markdown]
# **multiplication**

# %%
a=33
b=55
c=a*b
print(c)
# Out:
# 1815

# %% [markdown]
# # division

# %%
a+22
b=23
c=a/b
print(c)
# Out:
# 0.8695652173913043

# %% [markdown]
# Modulus

# %%
a=5
b=3
c=a%b
print(c)
# Out:
# 2

# %% [markdown]
# **Cambarison operators **
#
# Equal           x==y
#
# Not equal       x!=y
#
# Greator than
# or equal to     x>=y
#
# less than
#  equal to       x<=y

# %%
x=90
y=20
print(x == y)
# Out:
# False

# %%
x=20
y=30
print(x!=y)
# Out:
# True

# %%
x=10
y=20
print(x>=y)
# Out:
# False

# %%
x=20
y=10
print(x<=y)
# Out:
# False

# %%
x="hello"
y=123
print(type(x) == type(y))
# Out:
# False

# %% [markdown]
# **Logical Operators**

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
not True
# Out:
# False

# %%
x=90
y=20
print(x ==y and x!=y)
# Out:
# False

# %%
x=20
y=30
print(not (x == y or x!=y))
# Out:
# False

# %%
x=True
y=not x
print(y)
# Out:
# False

# %% [markdown]
# **Identity Operators**
#
#
# is,is not

# %%
a=70
b=40
print(a is b)
# Out:
# False

# %%
a=70
b=40
print(type(a) is type(b))
# Out:
# True

# %% [markdown]
# **Membership Operators**
#
# in,not in

# %%
x="hello"
print('e' in x)
# Out:
# True

# %%
x="hello"
print('e' not in x)
# Out:
# False

# %%
x="hello how are you"
print("how" in x )
# Out:
# True

# %% [markdown]
# # BITWISE OPERATORS
#  AND x&y
#
#  OR x/y
#
#  XOR x^y
#
#  NOT x!
